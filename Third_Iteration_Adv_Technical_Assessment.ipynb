# %% [markdown]
# <a href="https://colab.research.google.com/github/KML-Fig09/ComputerPeripherals/blob/FirstBranch/Third_Iteration_Adv_Technical_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installation module
# for necessary libraries

# !pip install torch torchvision yolov5 opencv-python pillow==10.3.0 gitpython onnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 22.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
# Setup module

import os
from pathlib import Path
from git import Repo

# Constants
BASE_PATH = Path('/content')
DATASET_ZIP = BASE_PATH / 'Raava.v1i.yolov5pytorch.zip'
DATASET_DIR = BASE_PATH / 'ComputerPeripherals'
YOLOV5_REPO = 'https://github.com/ultralytics/yolov5'
CUSTOM_REPO = 'https://github.com/KML-Fig09/ComputerPeripherals.git'
CUSTOM_REPO_DIR = BASE_PATH / 'custom_repo'

# Helper functions
def clone_repo(url, clone_dir):
    if not clone_dir.exists():
        Repo.clone_from(url, clone_dir)

def unzip_dataset(zip_path, extract_to):
    # !unzip {zip_path} -d {extract_to}

# Clone YOLOv5 and Custom Repository
clone_repo(YOLOV5_REPO, BASE_PATH / 'yolov5')
clone_repo(CUSTOM_REPO, CUSTOM_REPO_DIR)

# Unzip Dataset
unzip_dataset(DATASET_ZIP, DATASET_DIR)
# Out:
# Archive:  /content/Raava.v1i.yolov5pytorch.zip
#  extracting: /content/ComputerPeripherals/README.dataset.txt
#  extracting: /content/ComputerPeripherals/README.roboflow.txt
#  extracting: /content/ComputerPeripherals/data.yaml
#    creating: /content/ComputerPeripherals/test/
#    creating: /content/ComputerPeripherals/test/images/
#  extracting: /content/ComputerPeripherals/test/images/0086a3b797592fdf_jpg.rf.9e47c5125af9de8f8fb4ea3db44bea93.jpg
#  extracting: /content/ComputerPeripherals/test/images/0127ef6caff2e9c9_jpg.rf.687bc6c7f51ef5841982a5b05dfcc43d.jpg
#  extracting: /content/ComputerPeripherals/test/images/02fd4c43a6a2ee0b_jpg.rf.001bf9fc903a7fea391174d9ad54b4cf.jpg
#  extracting: /content/ComputerPeripherals/test/images/03bc463749f09a59_jpg.rf.8a778fcd6c3327a034f2206bb3e2cb9c.jpg
#  extracting: /content/ComputerPeripherals/test/images/058e28426f9b1373_jpg.rf.4198e33ba15bc897516da3b871648d62.jpg
# ...

# %%
# more troubleshooting, CBAM edition

# Ensure you are in the correct directory
import os
os.chdir('/content/yolov5')

# Verify files
# !ls /content/yolov5/models

# Add models directory to Python path
import sys
sys.path.append('/content/yolov5/models')

# Import CBAM
try:
    from cbam import CBAM
    print("CBAM module imported successfully!")
except ModuleNotFoundError as e:
    print(f"Error: {e}")

# Proceed with the rest of your script
# Out:
# cbam.py    experimental.py  __init__.py  tf.py	  yolov5l.yaml	yolov5n.yaml  yolov5x.yaml
# common.py  hub		    segment	 yolo.py  yolov5m.yaml	yolov5s.yaml
# CBAM module imported successfully!

# %%
# Training Module


def train_model(data_yaml, config_file, hyp_file):
    # !python /content/yolov5/train.py --img 640 --batch 16 --epochs 5 --data {data_yaml} --cfg {config_file} --weights '' --name custom_model --hyp {hyp_file}

# Customize: Update paths to your config, hyp file if needed
train_model(DATASET_DIR / 'data.yaml', BASE_PATH / 'yolov5/customyolov5.yaml', 'hyp.Objects365.yaml')
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 49, in <module>
#     from models.yolo import Model
#   File "/content/yolov5/models/yolo.py", line 8, in <module>
#     from cbam import CBAM
# ModuleNotFoundError: No module named 'cbam'

# %%
# Model Handling module

# %%
# Inference Module

# %%
# Export and deploy model
